# %% [markdown]
# # Soccer

# %%
import http.client

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-football-v1.p.rapidapi.com",
    'x-rapidapi-key': "c7b8d10f7amsh9f419bbc4156315p1899c9jsndd7b6c6a6600"
    }

conn.request("GET", "/v2/predictions/157462", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"api":{"results":1,"predictions":[{"match_winner":"1","under_over":null,"goals_home":"-3.5","goals_away":"-1.5","advice":"Winner : Paris Saint Germain","winning_percent":{"home":"50%","draws":"50%","away":"0%"},"teams":{"home":{"team_id":85,"team_name":"Paris Saint Germain","last_5_matches":{"forme":"75%","att":"71%","def":"86%","goals":10,"goals_avg":2.5,"goals_against":2,"goals_against_avg":0.5},"all_last_matches":{"matchs":{"matchsPlayed":{"home":2,"away":2,"total":4},"wins":{"home":2,"away":1,"total":3},"draws":{"home":0,"away":0,"total":0},"loses":{"home":0,"away":1,"total":1}},"goals":{"goalsFor":{"home":7,"away":3,"total":10},"goalsAgainst":{"home":0,"away":2,"total":2}},"goalsAvg":{"goalsFor":{"home":"3.5","away":"1.5","total":"2.5"},"goalsAgainst":{"home":"0.0","away":"1.0","total":"0.5"}}},"last_h2h":{"played":{"home":4,"away":3,"total":7},"wins":{"home":3,"away":1,"total":4},"draws":{"home":1,"away":1,"total":2},"loses":{"home":0,"away":1,"total":1}}},"away":{"team_id":95
# ...

# %% [markdown]
# # Basket

# %%
import http.client

conn = http.client.HTTPSConnection("api-basketball.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "api-basketball.p.rapidapi.com",
    'x-rapidapi-key': "c7b8d10f7amsh9f419bbc4156315p1899c9jsndd7b6c6a6600"
    }

conn.request("GET", "/leagues", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"get":"leagues","parameters":[],"errors":[],"results":116,"response":[{"id":18,"name":"Liga A","type":"League","logo":"https:\/\/media.api-sports.io\/basketball\/leagues\/18.png","country":{"id":6,"name":"Argentina","code":"AR","flag":"https:\/\/media.api-sports.io\/flags\/ar.svg"},"seasons":[{"season":"2019-2020","start":"2019-11-10","end":"2020-04-30"},{"season":"2018-2019","start":"2018-12-05","end":"2019-05-28"},{"season":"2017-2018","start":"2017-11-29","end":"2018-06-23"},{"season":"2016-2017","start":"2016-09-23","end":"2017-07-16"}]},{"id":22,"name":"Torneo Super 20","type":"cup","logo":"https:\/\/media.api-sports.io\/basketball\/leagues\/22.png","country":{"id":6,"name":"Argentina","code":"AR","flag":"https:\/\/media.api-sports.io\/flags\/ar.svg"},"seasons":[{"season":2019,"start":"2019-09-26","end":"2020-01-26"},{"season":2018,"start":"2018-09-23","end":"2018-12-23"},{"season":2017,"start":"2017-09-21","end":"2017-11-19"}]},{"id":6,"name":"ABL","type":"League","logo":"http
# ...
